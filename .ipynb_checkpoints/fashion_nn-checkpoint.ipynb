# %%
# %pip install torchvision 1>/dev/null

import torch
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

train_dataloader = DataLoader(training_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
from torch import nn

class FashionNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.sequential = nn.Sequential(
            nn.Linear(784, 512),
            nn.Dropout(),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.Dropout(),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, inp):
        flat = self.flatten(inp)
        return self.sequential(flat)

model = FashionNet().to(device)

model
# Out:
# FashionNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (sequential): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): Dropout(p=0.5, inplace=False)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): Dropout(p=0.5, inplace=False)
#     (5): ReLU()
#     (6): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Test feedforward with random weights
# Should return garbage

# %%
X_0, y_0 = training_data[0]
X_0 = X_0.to(device)

with torch.no_grad():
    y_0p = model(X_0)
    print(y_0p)
# Out:
# tensor([[ 0.0549, -0.0633, -0.0229, -0.2644,  0.0706,  0.0604,  0.0638,  0.0352,
#          -0.0509,  0.0089]], device='cuda:0')

# %%
X.shape, y
# Out:
# (torch.Size([1, 28, 28]), 9)

# %% [markdown]
# # Training Time

# %%
learning_rate = 1e-3
batch_size = 64
epochs = 5

loss_fn = nn.CrossEntropyLoss()

def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test_loop(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 30
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.976743  [   64/60000]
# loss: 1.012457  [ 6464/60000]
# loss: 0.796001  [12864/60000]
# loss: 0.942723  [19264/60000]
# loss: 0.883082  [25664/60000]
# loss: 0.953080  [32064/60000]
# loss: 0.950375  [38464/60000]
# loss: 0.942960  [44864/60000]
# loss: 0.919601  [51264/60000]
# loss: 0.836166  [57664/60000]
# Test Error:
#  Accuracy: 68.2%, Avg loss: 0.817367
#
# Epoch 2
# -------------------------------
# loss: 0.957716  [   64/60000]
# loss: 0.976973  [ 6464/60000]
# loss: 0.737151  [12864/60000]
# loss: 0.906452  [19264/60000]
# loss: 0.840190  [25664/60000]
# loss: 0.925247  [32064/60000]
# loss: 0.840458  [38464/60000]
# loss: 0.983200  [44864/60000]
# loss: 0.994945  [51264/60000]
# loss: 0.863719  [57664/60000]
# Test Error:
#  Accuracy: 69.1%, Avg loss: 0.794104
#
# Epoch 3
# -------------------------------
# loss: 0.902598  [   64/60000]
# loss: 0.921405  [ 6464/60000]
# loss: 0.719639  [12864/60000]
# loss: 0.941800  [19264/60000]
# loss: 0.814666  [25664/60000]
# loss: 0.829271  [32064/60000]
# loss: 0.938784  [38464/60000]
# loss: 0.843032  [44864/60000]
# loss: 0.893136  [51264/60000]
# loss: 0.845232  [57664/60000]
# Test Error:
#  Accuracy: 69.5%, Avg loss: 0.774939
#
# Epoch 4
# -------------------------------
# loss: 0.872966  [   64/60000]
# loss: 0.878571  [ 6464/60000]
# loss: 0.726651  [12864/60000]
# loss: 0.853333  [19264/60000]
# loss: 0.852672  [25664/60000]
# loss: 0.860010  [32064/60000]
# loss: 0.906258  [38464/60000]
# loss: 0.840396  [44864/60000]
# loss: 0.928970  [51264/60000]
# loss: 0.848615  [57664/60000]
# Test Error:
#  Accuracy: 70.4%, Avg loss: 0.757568
#
# Epoch 5
# -------------------------------
# loss: 0.796813  [   64/60000]
# loss: 0.885737  [ 6464/60000]
# loss: 0.639525  [12864/60000]
# loss: 0.901979  [19264/60000]
# loss: 0.758645  [25664/60000]
# loss: 0.842861  [32064/60000]
# loss: 0.872455  [38464/60000]
# loss: 0.842459  [44864/60000]
# loss: 0.844086  [51264/60000]
# loss: 0.827817  [57664/60000]
# Test Error:
#  Accuracy: 71.3%, Avg loss: 0.742635
#
# Epoch 6
# -------------------------------
# loss: 0.793824  [   64/60000]
# loss: 0.821908  [ 6464/60000]
# loss: 0.608289  [12864/60000]
# loss: 0.865535  [19264/60000]
# loss: 0.791256  [25664/60000]
# loss: 0.728733  [32064/60000]
# loss: 0.853739  [38464/60000]
# loss: 0.854551  [44864/60000]
# loss: 0.909182  [51264/60000]
# loss: 0.823224  [57664/60000]
# Test Error:
#  Accuracy: 71.9%, Avg loss: 0.728915
#
# Epoch 7
# -------------------------------
# loss: 0.697349  [   64/60000]
# loss: 0.818248  [ 6464/60000]
# loss: 0.655647  [12864/60000]
# loss: 0.834733  [19264/60000]
# loss: 0.812848  [25664/60000]
# loss: 0.836301  [32064/60000]
# loss: 0.855898  [38464/60000]
# loss: 0.828576  [44864/60000]
# loss: 0.931903  [51264/60000]
# loss: 0.844862  [57664/60000]
# Test Error:
#  Accuracy: 72.7%, Avg loss: 0.716312
#
# Epoch 8
# -------------------------------
# loss: 0.731613  [   64/60000]
# loss: 0.810918  [ 6464/60000]
# loss: 0.640234  [12864/60000]
# loss: 0.887003  [19264/60000]
# loss: 0.795546  [25664/60000]
# loss: 0.752406  [32064/60000]
# loss: 0.853371  [38464/60000]
# loss: 0.787192  [44864/60000]
# loss: 0.857794  [51264/60000]
# loss: 0.770586  [57664/60000]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.704768
#
# Epoch 9
# -------------------------------
# loss: 0.710761  [   64/60000]
# loss: 0.789896  [ 6464/60000]
# loss: 0.612824  [12864/60000]
# loss: 0.856772  [19264/60000]
# loss: 0.789444  [25664/60000]
# loss: 0.765326  [32064/60000]
# loss: 0.853478  [38464/60000]
# loss: 0.782077  [44864/60000]
# loss: 0.861283  [51264/60000]
# loss: 0.787188  [57664/60000]
# Test Error:
#  Accuracy: 73.7%, Avg loss: 0.693862
#
# Epoch 10
# -------------------------------
# loss: 0.692813  [   64/60000]
# loss: 0.851263  [ 6464/60000]
# loss: 0.618431  [12864/60000]
# loss: 0.858380  [19264/60000]
# loss: 0.767252  [25664/60000]
# loss: 0.661021  [32064/60000]
# loss: 0.828936  [38464/60000]
# loss: 0.800583  [44864/60000]
# loss: 0.870104  [51264/60000]
# loss: 0.795447  [57664/60000]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.683477
#
# Epoch 11
# -------------------------------
# loss: 0.712857  [   64/60000]
# loss: 0.791061  [ 6464/60000]
# loss: 0.551602  [12864/60000]
# loss: 0.843396  [19264/60000]
# loss: 0.805680  [25664/60000]
# loss: 0.757061  [32064/60000]
# loss: 0.750691  [38464/60000]
# loss: 0.803496  [44864/60000]
# loss: 0.813246  [51264/60000]
# loss: 0.750163  [57664/60000]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.673380
#
# Epoch 12
# -------------------------------
# loss: 0.702446  [   64/60000]
# loss: 0.768237  [ 6464/60000]
# loss: 0.551518  [12864/60000]
# loss: 0.827051  [19264/60000]
# loss: 0.767119  [25664/60000]
# loss: 0.716078  [32064/60000]
# loss: 0.745506  [38464/60000]
# loss: 0.844168  [44864/60000]
# loss: 0.745453  [51264/60000]
# loss: 0.798578  [57664/60000]
# Test Error:
#  Accuracy: 75.3%, Avg loss: 0.663956
#
# Epoch 13
# -------------------------------
# loss: 0.700879  [   64/60000]
# loss: 0.752957  [ 6464/60000]
# loss: 0.578449  [12864/60000]
# loss: 0.784444  [19264/60000]
# loss: 0.699561  [25664/60000]
# loss: 0.655639  [32064/60000]
# loss: 0.796095  [38464/60000]
# loss: 0.734443  [44864/60000]
# loss: 0.778456  [51264/60000]
# loss: 0.750643  [57664/60000]
# Test Error:
#  Accuracy: 75.7%, Avg loss: 0.655513
#
# Epoch 14
# -------------------------------
# loss: 0.735712  [   64/60000]
# loss: 0.797223  [ 6464/60000]
# loss: 0.556914  [12864/60000]
# loss: 0.779790  [19264/60000]
# loss: 0.714789  [25664/60000]
# loss: 0.740817  [32064/60000]
# loss: 0.769639  [38464/60000]
# loss: 0.768311  [44864/60000]
# loss: 0.835096  [51264/60000]
# loss: 0.739692  [57664/60000]
# Test Error:
#  Accuracy: 76.3%, Avg loss: 0.646696
#
# Epoch 15
# -------------------------------
# loss: 0.675728  [   64/60000]
# loss: 0.723657  [ 6464/60000]
# loss: 0.599370  [12864/60000]
# loss: 0.764000  [19264/60000]
# loss: 0.605315  [25664/60000]
# loss: 0.627037  [32064/60000]
# loss: 0.750045  [38464/60000]
# loss: 0.746930  [44864/60000]
# loss: 0.770916  [51264/60000]
# loss: 0.703931  [57664/60000]
# Test Error:
#  Accuracy: 76.6%, Avg loss: 0.638825
#
# Epoch 16
# -------------------------------
# loss: 0.656216  [   64/60000]
# loss: 0.737259  [ 6464/60000]
# loss: 0.499314  [12864/60000]
# loss: 0.779818  [19264/60000]
# loss: 0.703444  [25664/60000]
# loss: 0.696614  [32064/60000]
# loss: 0.692126  [38464/60000]
# loss: 0.858039  [44864/60000]
# loss: 0.767333  [51264/60000]
# loss: 0.674437  [57664/60000]
# Test Error:
#  Accuracy: 76.9%, Avg loss: 0.630980
#
# Epoch 17
# -------------------------------
# loss: 0.670779  [   64/60000]
# loss: 0.787564  [ 6464/60000]
# loss: 0.541033  [12864/60000]
# loss: 0.743376  [19264/60000]
# loss: 0.655063  [25664/60000]
# loss: 0.625333  [32064/60000]
# loss: 0.760490  [38464/60000]
# loss: 0.733168  [44864/60000]
# loss: 0.811254  [51264/60000]
# loss: 0.686367  [57664/60000]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.623768
#
# Epoch 18
# -------------------------------
# loss: 0.663379  [   64/60000]
# loss: 0.697518  [ 6464/60000]
# loss: 0.494028  [12864/60000]
# loss: 0.766267  [19264/60000]
# loss: 0.725340  [25664/60000]
# loss: 0.670117  [32064/60000]
# loss: 0.728277  [38464/60000]
# loss: 0.816433  [44864/60000]
# loss: 0.780109  [51264/60000]
# loss: 0.708099  [57664/60000]
# Test Error:
#  Accuracy: 77.6%, Avg loss: 0.616528
#
# Epoch 19
# -------------------------------
# loss: 0.572201  [   64/60000]
# loss: 0.701517  [ 6464/60000]
# loss: 0.531743  [12864/60000]
# loss: 0.797925  [19264/60000]
# loss: 0.700317  [25664/60000]
# loss: 0.698640  [32064/60000]
# loss: 0.743485  [38464/60000]
# loss: 0.711448  [44864/60000]
# loss: 0.786485  [51264/60000]
# loss: 0.672907  [57664/60000]
# Test Error:
#  Accuracy: 77.9%, Avg loss: 0.609635
#
# Epoch 20
# -------------------------------
# loss: 0.623091  [   64/60000]
# loss: 0.712828  [ 6464/60000]
# loss: 0.513337  [12864/60000]
# loss: 0.711354  [19264/60000]
# loss: 0.634369  [25664/60000]
# loss: 0.622811  [32064/60000]
# loss: 0.683055  [38464/60000]
# loss: 0.681394  [44864/60000]
# loss: 0.731436  [51264/60000]
# loss: 0.694309  [57664/60000]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.603342
#
# Epoch 21
# -------------------------------
# loss: 0.645382  [   64/60000]
# loss: 0.727859  [ 6464/60000]
# loss: 0.505532  [12864/60000]
# loss: 0.780067  [19264/60000]
# loss: 0.553674  [25664/60000]
# loss: 0.607843  [32064/60000]
# loss: 0.605425  [38464/60000]
# loss: 0.652730  [44864/60000]
# loss: 0.677998  [51264/60000]
# loss: 0.685755  [57664/60000]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.597268
#
# Epoch 22
# -------------------------------
# loss: 0.558526  [   64/60000]
# loss: 0.679360  [ 6464/60000]
# loss: 0.510910  [12864/60000]
# loss: 0.689683  [19264/60000]
# loss: 0.706325  [25664/60000]
# loss: 0.660083  [32064/60000]
# loss: 0.682866  [38464/60000]
# loss: 0.744340  [44864/60000]
# loss: 0.656732  [51264/60000]
# loss: 0.614546  [57664/60000]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.591185
#
# Epoch 23
# -------------------------------
# loss: 0.617378  [   64/60000]
# loss: 0.682785  [ 6464/60000]
# loss: 0.466558  [12864/60000]
# loss: 0.733862  [19264/60000]
# loss: 0.671714  [25664/60000]
# loss: 0.636872  [32064/60000]
# loss: 0.730821  [38464/60000]
# loss: 0.690907  [44864/60000]
# loss: 0.773744  [51264/60000]
# loss: 0.629266  [57664/60000]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.585888
#
# Epoch 24
# -------------------------------
# loss: 0.579227  [   64/60000]
# loss: 0.653160  [ 6464/60000]
# loss: 0.426814  [12864/60000]
# loss: 0.749469  [19264/60000]
# loss: 0.664381  [25664/60000]
# loss: 0.613186  [32064/60000]
# loss: 0.615532  [38464/60000]
# loss: 0.716529  [44864/60000]
# loss: 0.754326  [51264/60000]
# loss: 0.662874  [57664/60000]
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.580320
#
# Epoch 25
# -------------------------------
# loss: 0.628913  [   64/60000]
# loss: 0.682522  [ 6464/60000]
# loss: 0.463083  [12864/60000]
# loss: 0.734200  [19264/60000]
# loss: 0.659373  [25664/60000]
# loss: 0.593954  [32064/60000]
# loss: 0.691427  [38464/60000]
# loss: 0.651451  [44864/60000]
# loss: 0.720675  [51264/60000]
# loss: 0.614342  [57664/60000]
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.575506
#
# Epoch 26
# -------------------------------
# loss: 0.550868  [   64/60000]
# loss: 0.702621  [ 6464/60000]
# loss: 0.505537  [12864/60000]
# loss: 0.686617  [19264/60000]
# loss: 0.626407  [25664/60000]
# loss: 0.601826  [32064/60000]
# loss: 0.620117  [38464/60000]
# loss: 0.692201  [44864/60000]
# loss: 0.801717  [51264/60000]
# loss: 0.646483  [57664/60000]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.570440
#
# Epoch 27
# -------------------------------
# loss: 0.573371  [   64/60000]
# loss: 0.600438  [ 6464/60000]
# loss: 0.460324  [12864/60000]
# loss: 0.702910  [19264/60000]
# loss: 0.601603  [25664/60000]
# loss: 0.595435  [32064/60000]
# loss: 0.685084  [38464/60000]
# loss: 0.741066  [44864/60000]
# loss: 0.710485  [51264/60000]
# loss: 0.667183  [57664/60000]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.565983
#
# Epoch 28
# -------------------------------
# loss: 0.531424  [   64/60000]
# loss: 0.662136  [ 6464/60000]
# loss: 0.383392  [12864/60000]
# loss: 0.784505  [19264/60000]
# loss: 0.623278  [25664/60000]
# loss: 0.649477  [32064/60000]
# loss: 0.641270  [38464/60000]
# loss: 0.691089  [44864/60000]
# loss: 0.704252  [51264/60000]
# loss: 0.637770  [57664/60000]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.561148
#
# Epoch 29
# -------------------------------
# loss: 0.502986  [   64/60000]
# loss: 0.660222  [ 6464/60000]
# loss: 0.455680  [12864/60000]
# loss: 0.760607  [19264/60000]
# loss: 0.535184  [25664/60000]
# loss: 0.593255  [32064/60000]
# loss: 0.597180  [38464/60000]
# loss: 0.678236  [44864/60000]
# loss: 0.660209  [51264/60000]
# loss: 0.728961  [57664/60000]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.557373
#
# Epoch 30
# -------------------------------
# loss: 0.592592  [   64/60000]
# loss: 0.652215  [ 6464/60000]
# loss: 0.442444  [12864/60000]
# loss: 0.720810  [19264/60000]
# loss: 0.597753  [25664/60000]
# loss: 0.568925  [32064/60000]
# loss: 0.621689  [38464/60000]
# loss: 0.732497  [44864/60000]
# loss: 0.746353  [51264/60000]
# loss: 0.602171  [57664/60000]
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.552523
#
# Done!
